# %% [markdown]
# <a href="https://colab.research.google.com/github/Faxriddin2oo2/python-javoblarim/blob/main/first_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Assalomu alaykum!")
# Out:
# Assalomu alaykum!

# %% [markdown]
# # Heading
# - [Kirish](https://mohirdev.uz)
# - Muqaddima

# %%
import pandas as pd
import numpy as np
import tensorflow

# %%
tensorflow.__version__
# Out:
# '2.17.1'

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
! ls
# Out:
# sample_data
